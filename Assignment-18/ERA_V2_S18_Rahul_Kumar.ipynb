# %%
# !pip install datasets -q --quiet
# !pip install tokenizers -q --quiet
# !pip install torchmetrics -q --quiet
#!pip install torchtext -q --quiet

# !pip install --upgrade torch -q --quiet
# !pip install --upgrade torchtext -q --quiet

# !pip uninstall torchtext torch -y -q --quiet
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118 -q --quiet
# !pip install torchtext==0.15.1 -q --quiet # install compatible version based on official documentation
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 2.5.0 which is incompatible.
# torchtext 0.15.1 requires torch==2.0.0, but you have torch 2.5.0 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 2.5.0+cu118 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.0+cu121 requires torch==2.5.0, but you have torch 2.0.0 which is incompatible.
# torchvision 0.20.0+cu121 requires torch==2.5.0, but you have torch 2.0.0 which is incompatible.

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 64
cfg['preload'] = None

# %%
from train import train_model
import torch
torch.cuda.amp.autocast(enabled=True)

# %%
train_model(cfg)
# Out:
# Using device: cuda
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/28.1k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/5.73M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Max length of source sentence: 309
# Max length of target sentence: 274
# Processing Epoch 00: 100%|██████████| 243/243 [00:53<00:00,  4.54it/s, loss=6.130]
# ...
